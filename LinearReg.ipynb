# %%
#Machine Learning Linear Regression

# %%
# Step - 1 : import dataset

# %%
import pandas as pd
import numpy as np
df= pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
# Step - 2: Splitting dataset into training data and testing data (20% testing & 80% training)

# %%
x=  df[['cgpa']]
y= df['package']

# %%
x.head()
# Out:
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# Name: cgpa, dtype: float64

# %%
y.head()
# Out:
# 0    3.26
# 1    1.98
# 2    3.25
# 3    3.67
# 4    3.57
# Name: package, dtype: float64

# %%
#import library and select model as well to split
from sklearn.model_selection import train_test_split
x_test, x_train, y_test, y_train= train_test_split(x, y,
